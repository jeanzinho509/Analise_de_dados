# %% [markdown]
# <a href="https://colab.research.google.com/github/jeanzinho509/Analise_de_dados/blob/main/Segundo_exemplo_em_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Segundo exemplo de manipulação de dados usando Python Pandas**
#
# Veremos inserção de dados, remoção de colunas, merge, gráficos
#
# Auto: Jean Woodly Estime
#
# Data: 9 e 10 de fevereiro de 2023

# %%
#Importando biblioteca pandas no Python
import pandas as pd

# %%
combustiveis_df = pd.read_excel("ca202102.xlsx")
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
#Inserção simples de dado
combustiveis_df['Ativo'] = True

display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# ...

# %%
from numpy.lib.function_base import disp
# Criar uma coluna "Obs" que tenha nela escrito "MELHOR CIDADE" quando a coluna Municipio for igual a RIO DE JANEIRO
combustiveis_df['Obs'] = ["MELHOR CIDADE" if municipio == 'RIO DE JANEIRO' else '' for municipio in combustiveis_df['Municipio']]
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(['RIO DE JANEIRO','NITEROI', 'ANGRA DOS REIS', 'SAQUAREMA']), ['Municipio', 'Obs']])
# Out:
#              Municipio            Obs
# 738     ANGRA DOS REIS
# 739     ANGRA DOS REIS
# 740     ANGRA DOS REIS
# 741     ANGRA DOS REIS
# 742     ANGRA DOS REIS
# ...                ...            ...
# 161886       SAQUAREMA
# 161972  RIO DE JANEIRO  MELHOR CIDADE
# 161973  RIO DE JANEIRO  MELHOR CIDADE
# 161974  RIO DE JANEIRO  MELHOR CIDADE
# 161975  RIO DE JANEIRO  MELHOR CIDADE
#
# [3690 rows x 2 columns]

# %%
#como preencher uma coluna 'Valor de Venda - Status' que verifica o seguinte :
# Se o valor de venda for maior que 6,5 reais, ele fala que ta Caro.. caso contrario, está barato
import numpy as np

combustiveis_df['Status do Valor de Venda'] = np.where(combustiveis_df['Valor de Venda'] > 6.5, 'Caro', 'Barato')
display(combustiveis_df[['Revenda', 'Valor de Venda', 'Status do Valor de Venda']])
# Out:
#                                            Revenda  Valor de Venda  \
# 0                             POSTO ARAPIRACA LTDA           6.799
# 1                             POSTO ARAPIRACA LTDA           5.299
# 2                             POSTO ARAPIRACA LTDA           5.549
# 3                             POSTO ARAPIRACA LTDA           6.899
# 4                             POSTO ARAPIRACA LTDA           5.649
# ...                                            ...             ...
# 168404  COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA           5.859
# 168405           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
# 168406           ABC DISTRIBUICAO DE PETROLEO LTDA           4.740
# 168407           ABC DISTRIBUICAO DE PETROLEO LTDA           5.448
# 168408           ABC DISTRIBUICAO DE PETROLEO LTDA           6.580
#
#        Status do Valor de Venda
# 0                          Caro
# 1                        Barato
# 2                        Barato
# ...

# %%
#Calcular postos por habitante temos na mostragem de combustiveis nov/2021

habitantes_city_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
habitantes_city_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)
display(habitantes_city_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# ...

# %%
#Fazer um MERGE dos dois dataframes
colunas = ['Municipio', 'Estado - Sigla']
merge_df = combustiveis_df.merge(habitantes_city_df, how="inner", on=colunas)
display(merge_df)
print(merge_df.info())
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...

# %%
#Destruir coluna completamente vazia (todas as linhas são nulas)
merge_df.dropna(axis='columns', inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Regiao - Sigla            20634 non-null  object
#  1   Estado - Sigla            20634 non-null  object
#  2   Municipio                 20634 non-null  object
#  3   Revenda                   20634 non-null  object
#  4   CNPJ da Revenda           20634 non-null  object
#  5   Nome da Rua               20634 non-null  object
#  6   Numero Rua                20634 non-null  object
#  7   Bairro                    20634 non-null  object
#  8   Cep                       20634 non-null  object
#  9   Produto                   20634 non-null  object
#  10  Data da Coleta            20634 non-null  datetime64[ns]
#  11  Valor de Venda            20634 non-null  float64
#  12  Unidade de Medida         20634 non-null  object
# ...

# %%
colunas=['Regiao - Sigla', 'Nome da Rua', 'Numero Rua', 
         'Bairro', 'Cep', 'Produto', 'Data da Coleta', 'Valor de Venda',
         'Unidade de Medida', 'Bandeira', 'Ativo', 'Status do Valor de Venda']
merge_df.drop(labels=colunas, axis=1, inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estado - Sigla           20634 non-null  object
#  1   Municipio                20634 non-null  object
#  2   Revenda                  20634 non-null  object
#  3   CNPJ da Revenda          20634 non-null  object
#  4   Obs                      20634 non-null  object
#  5   Valor de Venda - Status  20634 non-null  object
#  6   NumHabitantes2021        20634 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.8+ MB
# None

# %%
display(merg_df.head(100))
# Out:
#    Regiao - Sigla Estado - Sigla Municipio                       Revenda  \
# 0              CO             GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1              CO             GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2              CO             GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3              CO             GO   GOIANIA             POSTO DO BOI LTDA
# 4              CO             GO   GOIANIA             POSTO DO BOI LTDA
# ..            ...            ...       ...                           ...
# 95             CO             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 96             CO             GO   GOIANIA   AUTO POSTO DONA SANTA LTDA.
# 97             CO             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 98             CO             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99             CO             GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
#
#         CNPJ da Revenda                     Nome da Rua Numero Rua  \
# ...

# %%
#Remoer as linhas duplicadas
merge_df.drop_duplicates(inplace=True)
display(merge_df.head(100))
# Out:
#     Estado - Sigla Municipio                           Revenda  \
# 0               GO   GOIANIA         AERO SETE AUTO POSTO LTDA
# 1               GO   GOIANIA         AERO SETE AUTO POSTO LTDA
# 3               GO   GOIANIA                 POSTO DO BOI LTDA
# 4               GO   GOIANIA                 POSTO DO BOI LTDA
# 7               GO   GOIANIA                     POSTO DN LTDA
# ..             ...       ...                               ...
# 182             GO   GOIANIA             AUTO POSTO LIDER LTDA
# 185             GO   GOIANIA       ALL ' FORTE AUTO POSTO LTDA
# 186             GO   GOIANIA       ALL ' FORTE AUTO POSTO LTDA
# 188             GO   GOIANIA  MARQUES DE CASTRO & GABRIEL LTDA
# 189             GO   GOIANIA  MARQUES DE CASTRO & GABRIEL LTDA
#
#          CNPJ da Revenda Obs Valor de Venda - Status  NumHabitantes2021
# 0     37.831.484/0001-20                           5            1555626
# ...

# %%
#Agrupar e contar quantos postos tem na cidade.
postos_por_munip_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_munip_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_munip_df.rename(columns={"Revenda": "Número de Postos"}, inplace=True)
display(postos_por_munip_df)
# Out:
#                                                  Número de Postos  Obs  \
# Estado - Sigla Municipio      NumHabitantes2021
# AC             RIO BRANCO     419452                           68   68
# GO             GOIANIA        1555626                         186  186
# MG             BELO HORIZONTE 2530701                         108  108
# MS             CAMPO GRANDE   916001                          208  208
# PR             CURITIBA       1963726                         219  219
# RJ             RIO DE JANEIRO 6775561                         749  749
# RN             NATAL          803739                           74   74
# RO             PORTO VELHO    548952                           74   74
# RS             PORTO ALEGRE   1492530                         131  131
# SP             CAMPINAS       1223237                         102  102
#                INDAIATUBA     260690                           71   71
# ...

# %%
#Agrupar e contar quantos postos tem na cidade
postos_por_munip_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_munip_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_munip_df.rename(columns={'Revenda': 'Numero de Postos'}, inplace=True)
postos_por_munip_df.reset_index(inplace=True)
display(postos_por_munip_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Numero de Postos  Obs  \
# 0              AC      RIO BRANCO             419452                68   68
# 1              GO         GOIANIA            1555626               186  186
# 2              MG  BELO HORIZONTE            2530701               108  108
# 3              MS    CAMPO GRANDE             916001               208  208
# 4              PR        CURITIBA            1963726               219  219
# 5              RJ  RIO DE JANEIRO            6775561               749  749
# 6              RN           NATAL             803739                74   74
# 7              RO     PORTO VELHO             548952                74   74
# 8              RS    PORTO ALEGRE            1492530               131  131
# 9              SP        CAMPINAS            1223237               102  102
# 10             SP      INDAIATUBA             260690                71   71
# ...

# %%
#Agrupar e contar quantos postos tem na cidade..
postos_por_munip_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_munip_df.reset_index(inplace=True)
#display(postos_por_municipio_df.info())
postos_por_munip_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_munip_df.rename(columns={"Revenda": "NumPostos"}, inplace=True)

postos_por_munip_df['PostosPorHabitante'] = postos_por_munip_df['NumPostos'] / postos_por_municipio_df['NumHabitantes2021']
display(postos_por_munip_df.info())
display(postos_por_munip_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Estado - Sigla           15 non-null     object
#  1   Municipio                15 non-null     object
#  2   NumHabitantes2021        15 non-null     int64
#  3   NumPostos                15 non-null     int64
#  4   Obs                      15 non-null     int64
#  5   Valor de Venda - Status  15 non-null     int64
#  6   PostosPorHabitante       15 non-null     float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 968.0+ bytes
# None
#    Estado - Sigla       Municipio  NumHabitantes2021  NumPostos  Obs  \
# 0              AC      RIO BRANCO             419452         68   68
# 1              GO         GOIANIA            1555626        186  186
# 2              MG  BELO HORIZONTE            2530701        108  108
# ...
